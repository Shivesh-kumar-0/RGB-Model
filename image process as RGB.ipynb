# %%
import skimage.io as io

# %%
import matplotlib.pyplot as plt

# %%
import numpy as np

# %%
img=io.imread('41964.jpg')

# %%
plt.imshow(img)

# %%
img.shape
# Out:
# (640, 360, 3)

# %%
#split

# %%
red=img[:,:,0]
green=img[:,:,1]
blue=img[:,:,2]

# %%
plt.imshow(red,cmap="Reds")

# %%
img.shape
# Out:
# (640, 360, 3)

# %%
plt.imshow(blue, cmap="Blues")

# %%
plt.show()

# %%
plt.imshow(blue, cmap="Greens")

# %%
plt.imshow(blue, cmap="Oranges")

# %%
plt.imshow(blue, cmap="Purples")
